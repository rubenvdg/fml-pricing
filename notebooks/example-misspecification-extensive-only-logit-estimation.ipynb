# %%
# %load_ext autoreload
# %autoreload 2

# %%
import numpy as np
from bnb.problem import OptimizationProblem
from matplotlib import pyplot as plt
import matplotlib
from scipy.optimize import minimize
import pandas as pd
from bnb.fml_solver import FMLSolver
import warnings
import time
import seaborn as sns
sns.set()
matplotlib.rcParams.update({'font.size': 11, 'font.family': 'serif'})

# %%
class DataSimulator(OptimizationProblem):
    
    def revenue_true(self, p):
        return np.sum([
            segment.w * np.sum(p * segment.purchase_probabilities(p))
            for segment in self.segments
        ])
    
    def simulate_choices(self, n_observations, seed=None):
        
        np.random.seed(seed)
        
        observed_prices = np.random.uniform(self.p_lb, self.p_ub, size=(n_observations, self.n))
        
        purchase_probabilities = np.asarray([
            np.sum([segment.w * segment.purchase_probabilities(price) for segment in self.segments], axis=0)
            for price in observed_prices
        ])
            
        assert purchase_probabilities.shape == (n_observations, self.n)
        
        # 0 is first product, n is no purchse
        observed_choices = np.sum(
            np.cumsum(purchase_probabilities, axis=1) < np.random.uniform(size=(n_observations, 1)),
            axis=1
        )
        
        return observed_prices, observed_choices
    
    
def logit_loglikelihood(params, observed_choices, observed_prices):
    
    a = params[:n]
    b = params[n:]
    n_choices = len(observed_choices)
    
    utilities = a - b * observed_prices
#     assert utilities.shape == (n_choices, n)
    
    utilities = np.c_[utilities, np.zeros((n_choices, 1))]
#     assert utilities.shape == (n_choices, n + 1)
    
    utilities_chosen_products = utilities[np.arange(n_choices), observed_choices]
#     assert utilities_chosen_products.shape == (n_choices, ), utilities_chosen_products.shape
    
    log_probs = - np.log(np.sum(np.exp(utilities - np.expand_dims(utilities_chosen_products, -1)), axis=-1))
#     assert log_probs.shape == (n_choices, ), log_probs.shape
    
    return - np.sum(log_probs) / n_choices

# %%
n = 10
results = []
n_choices = 1000
for m in [2, 3, 4]:
    print(f"m: {m}.")
    for run in range(100):
        print(f"run: {run}.")
        t0 = time.time()

        seed = n + m + run
        np.random.seed(seed)

        a0 = np.random.uniform(0, 4, size=(m, n))
        b0 = np.random.uniform(0.001, 0.01, size=n)
        w0 = np.random.uniform(size=m)
        w0 /= np.sum(w0)

        true_demand = DataSimulator(a0, b0, w0)
        solver = FMLSolver(true_demand)
        solver.solve()
        print(f"time elapsed after FML solver: {solver.timer}.")

        observed_prices, observed_choices = true_demand.simulate_choices(n_choices)

        a_start = np.ones((1, n))
        b_start = np.zeros(n)
        parameter_start = np.hstack((a_start.reshape(n), b_start))

        with warnings.catch_warnings():
            warnings.filterwarnings(action="ignore", category=RuntimeWarning)
            min_ll = minimize(logit_loglikelihood, parameter_start, args=(observed_choices, observed_prices))

        print(f"time elapsed after likelihood estimation: {time.time() - t0}.")
        # standard_errors = np.sqrt(np.diag(min_ll.hess_inv) / n_choices)
        a, b = min_ll.x[:n], min_ll.x[n:]
        # print("likelihood opt: ", min_ll.message)

        opt = OptimizationProblem(np.asarray([a]), b, np.ones(1))
        def logit_revenue(p, opt):
            assert len(opt.segments) == 1
            segment = opt.segments[0]
            return - np.sum(p * segment.purchase_probabilities(p))
        with warnings.catch_warnings():
            warnings.filterwarnings(action="ignore", category=RuntimeWarning)
            opt_rev = minimize(logit_revenue, np.ones(n) + 3.0, args=(opt, ))

        print(f"time elapsed after logit revenue optimization: {time.time() - t0}.")
        results.append({
            "n": n,
            "m": m,
            "seed": seed,
            "logit_rev": opt_rev,
            "fml_rev": (solver.objective_ub + solver.objective_lb) / 2,
            "log_ll_msg": min_ll.message,
            "logit_opt_msg": opt_rev.message,
        })

        # print("opt logit rev: ", opt_rev.message)
        # print("misspecified rev: ", - opt_rev.fun)
        # print("real rev: ", true_demand.revenue_true(opt_rev.x))
        # print("opt rev: ", solver.objective_ub)
        # print()
# Out:
# m: 2.
# run: 0.
# time elapsed after FML solver: 0.813007116317749.
# time elapsed after likelihood estimation: 1.7422006130218506.
# time elapsed after logit revenue optimization: 1.761819839477539.
# run: 1.
# time elapsed after FML solver: 0.7915558815002441.
# time elapsed after likelihood estimation: 1.6551790237426758.
# time elapsed after logit revenue optimization: 1.7017898559570312.
# run: 2.
# time elapsed after FML solver: 0.9408700466156006.
# time elapsed after likelihood estimation: 1.643984079360962.
# time elapsed after logit revenue optimization: 1.6939499378204346.
# run: 3.
# time elapsed after FML solver: 0.7964248657226562.
# time elapsed after likelihood estimation: 1.3520293235778809.
# time elapsed after logit revenue optimization: 1.4414043426513672.
# run: 4.
# time elapsed after FML solver: 0.7912290096282959.
# time elapsed after likelihood estimation: 1.2879230976104736.
# time elapsed after logit revenue optimization: 1.3207619190216064.
# run: 5.
# time elapsed after FML solver: 0.6287028789520264.
# time elapsed after likelihood estimation: 1.1309030055999756.
# time elapsed after logit revenue optimization: 1.1965827941894531.
# run: 6.
# time elapsed after FML solver: 0.7840750217437744.
# time elapsed after likelihood estimation: 1.4125430583953857.
# time elapsed after logit revenue optimization: 1.4920392036437988.
# run: 7.
# time elapsed after FML solver: 1.0913279056549072.
# time elapsed after likelihood estimation: 1.5298728942871094.
# time elapsed after logit revenue optimization: 1.5733299255371094.
# run: 8.
# time elapsed after FML solver: 0.7800219058990479.
# time elapsed after likelihood estimation: 1.5421299934387207.
# time elapsed after logit revenue optimization: 1.6042420864105225.
# run: 9.
# time elapsed after FML solver: 0.7841789722442627.
# time elapsed after likelihood estimation: 1.3775527477264404.
# time elapsed after logit revenue optimization: 1.4563891887664795.
# run: 10.
# time elapsed after FML solver: 0.9430751800537109.
# time elapsed after likelihood estimation: 1.5445811748504639.
# time elapsed after logit revenue optimization: 1.6311101913452148.
# run: 11.
# time elapsed after FML solver: 0.7922449111938477.
# time elapsed after likelihood estimation: 1.5842101573944092.
# time elapsed after logit revenue optimization: 1.6229071617126465.
# run: 12.
# time elapsed after FML solver: 0.9430902004241943.
# time elapsed after likelihood estimation: 1.4126150608062744.
# time elapsed after logit revenue optimization: 1.466698169708252.
# run: 13.
# time elapsed after FML solver: 0.9461460113525391.
# time elapsed after likelihood estimation: 1.753438949584961.
# time elapsed after logit revenue optimization: 1.822920799255371.
# run: 14.
# time elapsed after FML solver: 0.7870359420776367.
# time elapsed after likelihood estimation: 1.3800370693206787.
# time elapsed after logit revenue optimization: 1.4649572372436523.
# run: 15.
# time elapsed after FML solver: 0.9306988716125488.
# time elapsed after likelihood estimation: 1.6895852088928223.
# time elapsed after logit revenue optimization: 1.7901899814605713.
# run: 16.
# time elapsed after FML solver: 1.0845770835876465.
# time elapsed after likelihood estimation: 1.6998600959777832.
# time elapsed after logit revenue optimization: 1.8102951049804688.
# run: 17.
# time elapsed after FML solver: 0.936363935470581.
# time elapsed after likelihood estimation: 1.9066359996795654.
# time elapsed after logit revenue optimization: 1.9607343673706055.
# run: 18.
# time elapsed after FML solver: 0.9348270893096924.
# time elapsed after likelihood estimation: 1.6021709442138672.
# time elapsed after logit revenue optimization: 1.6356911659240723.
# run: 19.
# time elapsed after FML solver: 0.7768990993499756.
# time elapsed after likelihood estimation: 1.421457290649414.
# time elapsed after logit revenue optimization: 1.468682050704956.
# run: 20.
# time elapsed after FML solver: 0.7699940204620361.
# time elapsed after likelihood estimation: 1.3157150745391846.
# time elapsed after logit revenue optimization: 1.3746280670166016.
# run: 21.
# time elapsed after FML solver: 0.6211178302764893.
# time elapsed after likelihood estimation: 1.4020087718963623.
# time elapsed after logit revenue optimization: 1.452394962310791.
# run: 22.
# time elapsed after FML solver: 0.6206719875335693.
# time elapsed after likelihood estimation: 1.2917373180389404.
# time elapsed after logit revenue optimization: 1.3167312145233154.
# run: 23.
# time elapsed after FML solver: 1.094297170639038.
# time elapsed after likelihood estimation: 1.8408730030059814.
# time elapsed after logit revenue optimization: 1.868316888809204.
# run: 24.
# time elapsed after FML solver: 0.7916052341461182.
# time elapsed after likelihood estimation: 1.3864781856536865.
# time elapsed after logit revenue optimization: 1.450989007949829.
# run: 25.
# time elapsed after FML solver: 0.7844042778015137.
# time elapsed after likelihood estimation: 1.2923338413238525.
# time elapsed after logit revenue optimization: 1.3574600219726562.
# run: 26.
# time elapsed after FML solver: 0.9260869026184082.
# time elapsed after likelihood estimation: 1.431976079940796.
# time elapsed after logit revenue optimization: 1.502384901046753.
# run: 27.
# time elapsed after FML solver: 0.9514467716217041.
# time elapsed after likelihood estimation: 1.5353360176086426.
# time elapsed after logit revenue optimization: 1.5668962001800537.
# run: 28.
# time elapsed after FML solver: 1.1016759872436523.
# time elapsed after likelihood estimation: 1.6307382583618164.
# time elapsed after logit revenue optimization: 1.6814851760864258.
# run: 29.
# time elapsed after FML solver: 0.7801272869110107.
# time elapsed after likelihood estimation: 1.3979880809783936.
# time elapsed after logit revenue optimization: 1.456908941268921.
# run: 30.
# time elapsed after FML solver: 0.7702021598815918.
# time elapsed after likelihood estimation: 1.4671330451965332.
# time elapsed after logit revenue optimization: 1.521388053894043.
# run: 31.
# time elapsed after FML solver: 0.7828669548034668.
# time elapsed after likelihood estimation: 1.3439080715179443.
# time elapsed after logit revenue optimization: 1.4628701210021973.
# run: 32.
# time elapsed after FML solver: 0.9301309585571289.
# time elapsed after likelihood estimation: 1.5192179679870605.
# time elapsed after logit revenue optimization: 1.5422711372375488.
# run: 33.
# time elapsed after FML solver: 0.9435560703277588.
# time elapsed after likelihood estimation: 1.5266199111938477.
# time elapsed after logit revenue optimization: 1.5670599937438965.
# run: 34.
# time elapsed after FML solver: 0.9414868354797363.
# time elapsed after likelihood estimation: 1.708266019821167.
# time elapsed after logit revenue optimization: 1.7643868923187256.
# run: 35.
# time elapsed after FML solver: 0.7797679901123047.
# time elapsed after likelihood estimation: 1.4800801277160645.
# time elapsed after logit revenue optimization: 1.6005213260650635.
# run: 36.
# time elapsed after FML solver: 0.9315319061279297.
# time elapsed after likelihood estimation: 1.6074109077453613.
# time elapsed after logit revenue optimization: 1.6319220066070557.
# run: 37.
# time elapsed after FML solver: 1.1175148487091064.
# time elapsed after likelihood estimation: 1.8150701522827148.
# time elapsed after logit revenue optimization: 1.8501389026641846.
# run: 38.
# time elapsed after FML solver: 0.7896339893341064.
# time elapsed after likelihood estimation: 1.4384050369262695.
# time elapsed after logit revenue optimization: 1.455582857131958.
# run: 39.
# time elapsed after FML solver: 0.631317138671875.
# time elapsed after likelihood estimation: 1.0582029819488525.
# time elapsed after logit revenue optimization: 1.1103310585021973.
# run: 40.
# time elapsed after FML solver: 0.9393570423126221.
# time elapsed after likelihood estimation: 1.3877599239349365.
# time elapsed after logit revenue optimization: 1.4969429969787598.
# run: 41.
# time elapsed after FML solver: 0.6242589950561523.
# time elapsed after likelihood estimation: 1.1127328872680664.
# time elapsed after logit revenue optimization: 1.161395788192749.
# run: 42.
# time elapsed after FML solver: 0.7719581127166748.
# time elapsed after likelihood estimation: 1.3090612888336182.
# time elapsed after logit revenue optimization: 1.348107099533081.
# run: 43.
# time elapsed after FML solver: 0.931912899017334.
# time elapsed after likelihood estimation: 1.6174299716949463.
# time elapsed after logit revenue optimization: 1.6691679954528809.
# run: 44.
# time elapsed after FML solver: 0.7723867893218994.
# time elapsed after likelihood estimation: 1.6608531475067139.
# time elapsed after logit revenue optimization: 1.7003459930419922.
# run: 45.
# time elapsed after FML solver: 0.6220541000366211.
# time elapsed after likelihood estimation: 1.346008062362671.
# time elapsed after logit revenue optimization: 1.393895149230957.
# run: 46.
# time elapsed after FML solver: 0.6191329956054688.
# time elapsed after likelihood estimation: 1.5486018657684326.
# time elapsed after logit revenue optimization: 1.6119072437286377.
# run: 47.
# time elapsed after FML solver: 0.9411430358886719.
# time elapsed after likelihood estimation: 1.6108520030975342.
# time elapsed after logit revenue optimization: 1.7016229629516602.
# run: 48.
# time elapsed after FML solver: 0.9800851345062256.
# time elapsed after likelihood estimation: 1.8423881530761719.
# time elapsed after logit revenue optimization: 1.9123649597167969.
# run: 49.
# time elapsed after FML solver: 0.8326132297515869.
# time elapsed after likelihood estimation: 1.3736259937286377.
# time elapsed after logit revenue optimization: 1.403836965560913.
# run: 50.
# time elapsed after FML solver: 1.0200161933898926.
# time elapsed after likelihood estimation: 1.7143738269805908.
# time elapsed after logit revenue optimization: 1.8078978061676025.
# run: 51.
# time elapsed after FML solver: 0.9949378967285156.
# time elapsed after likelihood estimation: 1.8064157962799072.
# time elapsed after logit revenue optimization: 1.8213980197906494.
# run: 52.
# time elapsed after FML solver: 0.6524031162261963.
# time elapsed after likelihood estimation: 1.2692198753356934.
# time elapsed after logit revenue optimization: 1.3222301006317139.
# run: 53.
# time elapsed after FML solver: 0.8189702033996582.
# time elapsed after likelihood estimation: 1.3387629985809326.
# time elapsed after logit revenue optimization: 1.4218873977661133.
# run: 54.
# time elapsed after FML solver: 0.8487977981567383.
# time elapsed after likelihood estimation: 1.787856101989746.
# time elapsed after logit revenue optimization: 1.8307321071624756.
# run: 55.
# time elapsed after FML solver: 1.009829044342041.
# time elapsed after likelihood estimation: 1.684654951095581.
# time elapsed after logit revenue optimization: 1.7777600288391113.
# run: 56.
# time elapsed after FML solver: 0.9993999004364014.
# time elapsed after likelihood estimation: 1.6547222137451172.
# time elapsed after logit revenue optimization: 1.7539129257202148.
# run: 57.
# time elapsed after FML solver: 0.6644699573516846.
# time elapsed after likelihood estimation: 1.2008488178253174.
# time elapsed after logit revenue optimization: 1.2568697929382324.
# run: 58.
# time elapsed after FML solver: 0.8309781551361084.
# time elapsed after likelihood estimation: 1.5964899063110352.
# time elapsed after logit revenue optimization: 1.6145527362823486.
# run: 59.
# time elapsed after FML solver: 0.9923100471496582.
# time elapsed after likelihood estimation: 1.4764251708984375.
# time elapsed after logit revenue optimization: 1.5290942192077637.
# run: 60.
# time elapsed after FML solver: 0.8288109302520752.
# time elapsed after likelihood estimation: 1.6174919605255127.
# time elapsed after logit revenue optimization: 1.6845290660858154.
# run: 61.
# time elapsed after FML solver: 0.8181600570678711.
# time elapsed after likelihood estimation: 1.6833043098449707.
# time elapsed after logit revenue optimization: 1.7604773044586182.
# run: 62.
# time elapsed after FML solver: 0.8288531303405762.
# time elapsed after likelihood estimation: 1.623081922531128.
# time elapsed after logit revenue optimization: 1.659132719039917.
# run: 63.
# time elapsed after FML solver: 0.8237640857696533.
# time elapsed after likelihood estimation: 1.5804049968719482.
# time elapsed after logit revenue optimization: 1.629478931427002.
# run: 64.
# time elapsed after FML solver: 0.8302478790283203.
# time elapsed after likelihood estimation: 1.3947010040283203.
# time elapsed after logit revenue optimization: 1.4497849941253662.
# run: 65.
# time elapsed after FML solver: 0.8259167671203613.
# time elapsed after likelihood estimation: 1.7217979431152344.
# time elapsed after logit revenue optimization: 1.812891960144043.
# run: 66.
# time elapsed after FML solver: 0.9867262840270996.
# time elapsed after likelihood estimation: 1.6223728656768799.
# time elapsed after logit revenue optimization: 1.6459228992462158.
# run: 67.
# time elapsed after FML solver: 0.9852008819580078.
# time elapsed after likelihood estimation: 1.5839159488677979.
# time elapsed after logit revenue optimization: 1.6230158805847168.
# run: 68.
# time elapsed after FML solver: 0.8185629844665527.
# time elapsed after likelihood estimation: 1.3138031959533691.
# time elapsed after logit revenue optimization: 1.4027299880981445.
# run: 69.
# time elapsed after FML solver: 0.8278610706329346.
# time elapsed after likelihood estimation: 1.3675940036773682.
# time elapsed after logit revenue optimization: 1.439513921737671.
# run: 70.
# time elapsed after FML solver: 0.976032018661499.
# time elapsed after likelihood estimation: 2.016906976699829.
# time elapsed after logit revenue optimization: 2.061685085296631.
# run: 71.
# time elapsed after FML solver: 0.8165850639343262.
# time elapsed after likelihood estimation: 1.366541862487793.
# time elapsed after logit revenue optimization: 1.4584660530090332.
# run: 72.
# time elapsed after FML solver: 1.1293540000915527.
# time elapsed after likelihood estimation: 1.7953948974609375.
# time elapsed after logit revenue optimization: 1.8208658695220947.
# run: 73.
# time elapsed after FML solver: 0.9742259979248047.
# time elapsed after likelihood estimation: 2.098684310913086.
# time elapsed after logit revenue optimization: 2.168626308441162.
# run: 74.
# time elapsed after FML solver: 0.9884011745452881.
# time elapsed after likelihood estimation: 1.806581974029541.
# time elapsed after logit revenue optimization: 1.8443546295166016.
# run: 75.
# time elapsed after FML solver: 0.6670563220977783.
# time elapsed after likelihood estimation: 1.355078935623169.
# time elapsed after logit revenue optimization: 1.3870182037353516.
# run: 76.
# time elapsed after FML solver: 0.8304440975189209.
# time elapsed after likelihood estimation: 1.6666288375854492.
# time elapsed after logit revenue optimization: 1.696295976638794.
# run: 77.
# time elapsed after FML solver: 0.8209033012390137.
# time elapsed after likelihood estimation: 1.282498836517334.
# time elapsed after logit revenue optimization: 1.306260108947754.
# run: 78.
# time elapsed after FML solver: 0.8322441577911377.
# time elapsed after likelihood estimation: 1.7635002136230469.
# time elapsed after logit revenue optimization: 1.7915923595428467.
# run: 79.
# time elapsed after FML solver: 0.8276779651641846.
# time elapsed after likelihood estimation: 1.4258661270141602.
# time elapsed after logit revenue optimization: 1.443925142288208.
# run: 80.
# time elapsed after FML solver: 0.8265130519866943.
# time elapsed after likelihood estimation: 1.4726829528808594.
# time elapsed after logit revenue optimization: 1.517937183380127.
# run: 81.
# time elapsed after FML solver: 0.9773881435394287.
# time elapsed after likelihood estimation: 1.5894689559936523.
# time elapsed after logit revenue optimization: 1.6209790706634521.
# run: 82.
# time elapsed after FML solver: 0.8295722007751465.
# time elapsed after likelihood estimation: 1.4854209423065186.
# time elapsed after logit revenue optimization: 1.5228469371795654.
# run: 83.
# time elapsed after FML solver: 1.002148151397705.
# time elapsed after likelihood estimation: 1.6354658603668213.
# time elapsed after logit revenue optimization: 1.7051210403442383.
# run: 84.
# time elapsed after FML solver: 0.6597332954406738.
# time elapsed after likelihood estimation: 1.2695801258087158.
# time elapsed after logit revenue optimization: 1.3237650394439697.
# run: 85.
# time elapsed after FML solver: 1.1406950950622559.
# time elapsed after likelihood estimation: 1.580739974975586.
# time elapsed after logit revenue optimization: 1.7072529792785645.
# run: 86.
# time elapsed after FML solver: 1.0016589164733887.
# time elapsed after likelihood estimation: 1.8253979682922363.
# time elapsed after logit revenue optimization: 1.8633010387420654.
# run: 87.
# time elapsed after FML solver: 1.010193109512329.
# time elapsed after likelihood estimation: 1.6916379928588867.
# time elapsed after logit revenue optimization: 1.78462815284729.
# run: 88.
# time elapsed after FML solver: 0.8196008205413818.
# time elapsed after likelihood estimation: 1.4984157085418701.
# time elapsed after logit revenue optimization: 1.5173068046569824.
# run: 89.
# time elapsed after FML solver: 0.8249280452728271.
# time elapsed after likelihood estimation: 1.4215123653411865.
# time elapsed after logit revenue optimization: 1.5184619426727295.
# run: 90.
# time elapsed after FML solver: 0.988152027130127.
# time elapsed after likelihood estimation: 1.806570053100586.
# time elapsed after logit revenue optimization: 1.8337700366973877.
# run: 91.
# time elapsed after FML solver: 0.8197617530822754.
# time elapsed after likelihood estimation: 1.3715319633483887.
# time elapsed after logit revenue optimization: 1.4449689388275146.
# run: 92.
# time elapsed after FML solver: 0.8097250461578369.
# time elapsed after likelihood estimation: 1.37746000289917.
# time elapsed after logit revenue optimization: 1.461775779724121.
# run: 93.
# time elapsed after FML solver: 0.8260831832885742.
# time elapsed after likelihood estimation: 1.6275479793548584.
# time elapsed after logit revenue optimization: 1.6873550415039062.
# run: 94.
# time elapsed after FML solver: 1.154144048690796.
# time elapsed after likelihood estimation: 1.6551361083984375.
# time elapsed after logit revenue optimization: 1.710697889328003.
# run: 95.
# time elapsed after FML solver: 1.0006661415100098.
# time elapsed after likelihood estimation: 1.8801002502441406.
# time elapsed after logit revenue optimization: 1.9291901588439941.
# run: 96.
# time elapsed after FML solver: 0.8121483325958252.
# time elapsed after likelihood estimation: 1.352952003479004.
# time elapsed after logit revenue optimization: 1.3870110511779785.
# run: 97.
# time elapsed after FML solver: 0.984954833984375.
# time elapsed after likelihood estimation: 1.6982471942901611.
# time elapsed after logit revenue optimization: 1.7252249717712402.
# run: 98.
# time elapsed after FML solver: 0.8275527954101562.
# time elapsed after likelihood estimation: 1.625243902206421.
# time elapsed after logit revenue optimization: 1.6937599182128906.
# run: 99.
# time elapsed after FML solver: 0.9831128120422363.
# time elapsed after likelihood estimation: 1.6437358856201172.
# time elapsed after logit revenue optimization: 1.6920299530029297.
# m: 3.
# run: 0.
# time elapsed after FML solver: 2.7269933223724365.
# time elapsed after likelihood estimation: 3.5287280082702637.
# time elapsed after logit revenue optimization: 3.5574450492858887.
# run: 1.
# time elapsed after FML solver: 1.5432770252227783.
# time elapsed after likelihood estimation: 2.253751039505005.
# time elapsed after logit revenue optimization: 2.3036210536956787.
# run: 2.
# time elapsed after FML solver: 1.5127480030059814.
# time elapsed after likelihood estimation: 2.0930988788604736.
# time elapsed after logit revenue optimization: 2.1887619495391846.
# run: 3.
# time elapsed after FML solver: 4.226635932922363.
# time elapsed after likelihood estimation: 4.950250148773193.
# time elapsed after logit revenue optimization: 4.987411975860596.
# run: 4.
# time elapsed after FML solver: 2.0511651039123535.
# time elapsed after likelihood estimation: 2.798480749130249.
# time elapsed after logit revenue optimization: 2.832058906555176.
# run: 5.
# time elapsed after FML solver: 1.5720791816711426.
# time elapsed after likelihood estimation: 2.1909408569335938.
# time elapsed after logit revenue optimization: 2.266033887863159.
# run: 6.
# time elapsed after FML solver: 1.6174399852752686.
# time elapsed after likelihood estimation: 2.2620270252227783.
# time elapsed after logit revenue optimization: 2.3105478286743164.
# run: 7.
# time elapsed after FML solver: 2.641849994659424.
# time elapsed after likelihood estimation: 3.4094369411468506.
# time elapsed after logit revenue optimization: 3.443917751312256.
# run: 8.
# time elapsed after FML solver: 1.9381680488586426.
# time elapsed after likelihood estimation: 2.4481310844421387.
# time elapsed after logit revenue optimization: 2.576078176498413.
# run: 9.
# time elapsed after FML solver: 4.453145265579224.
# time elapsed after likelihood estimation: 5.532278776168823.
# time elapsed after logit revenue optimization: 5.597541809082031.
# run: 10.
# time elapsed after FML solver: 2.502002000808716.
# time elapsed after likelihood estimation: 3.187598705291748.
# time elapsed after logit revenue optimization: 3.220660924911499.
# run: 11.
# time elapsed after FML solver: 2.4736859798431396.
# time elapsed after likelihood estimation: 3.128483772277832.
# time elapsed after logit revenue optimization: 3.244086980819702.
# run: 12.
# time elapsed after FML solver: 2.0095160007476807.
# time elapsed after likelihood estimation: 2.53517484664917.
# time elapsed after logit revenue optimization: 2.606957197189331.
# run: 13.
# time elapsed after FML solver: 2.9529836177825928.
# time elapsed after likelihood estimation: 3.6818549633026123.
# time elapsed after logit revenue optimization: 3.721331834793091.
# run: 14.
# time elapsed after FML solver: 2.1912782192230225.
# time elapsed after likelihood estimation: 3.1355340480804443.
# time elapsed after logit revenue optimization: 3.188347101211548.
# run: 15.
# time elapsed after FML solver: 2.075029134750366.
# time elapsed after likelihood estimation: 2.734403133392334.
# time elapsed after logit revenue optimization: 2.7930731773376465.
# run: 16.
# time elapsed after FML solver: 1.9684081077575684.
# time elapsed after likelihood estimation: 2.531870126724243.
# time elapsed after logit revenue optimization: 2.5859529972076416.
# run: 17.
# time elapsed after FML solver: 1.5672450065612793.
# time elapsed after likelihood estimation: 2.1914124488830566.
# time elapsed after logit revenue optimization: 2.269487142562866.
# run: 18.
# time elapsed after FML solver: 2.0571789741516113.
# time elapsed after likelihood estimation: 2.682115077972412.
# time elapsed after logit revenue optimization: 2.717241048812866.
# run: 19.
# time elapsed after FML solver: 2.288379192352295.
# time elapsed after likelihood estimation: 3.1209311485290527.
# time elapsed after logit revenue optimization: 3.184953212738037.
# run: 20.
# time elapsed after FML solver: 3.2895238399505615.
# time elapsed after likelihood estimation: 4.017821311950684.
# time elapsed after logit revenue optimization: 4.064586400985718.
# run: 21.
# time elapsed after FML solver: 2.758890151977539.
# time elapsed after likelihood estimation: 3.4084980487823486.
# time elapsed after logit revenue optimization: 3.466097116470337.
# run: 22.
# time elapsed after FML solver: 2.067949056625366.
# time elapsed after likelihood estimation: 2.5992608070373535.
# time elapsed after logit revenue optimization: 2.6778676509857178.
# run: 23.
# time elapsed after FML solver: 3.571965217590332.
# time elapsed after likelihood estimation: 4.600178241729736.
# time elapsed after logit revenue optimization: 4.704419136047363.
# run: 24.
# time elapsed after FML solver: 1.1100108623504639.
# time elapsed after likelihood estimation: 1.886444091796875.
# time elapsed after logit revenue optimization: 1.9314970970153809.
# run: 25.
# time elapsed after FML solver: 4.3068811893463135.
# time elapsed after likelihood estimation: 5.1380040645599365.
# time elapsed after logit revenue optimization: 5.180436134338379.
# run: 26.
# time elapsed after FML solver: 1.5241262912750244.
# time elapsed after likelihood estimation: 2.4630541801452637.
# time elapsed after logit revenue optimization: 2.4822452068328857.
# run: 27.
# time elapsed after FML solver: 1.8322341442108154.
# time elapsed after likelihood estimation: 2.565274953842163.
# time elapsed after logit revenue optimization: 2.6069929599761963.
# run: 28.
# time elapsed after FML solver: 2.4952750205993652.
# time elapsed after likelihood estimation: 3.0013539791107178.
# time elapsed after logit revenue optimization: 3.0744330883026123.
# run: 29.
# time elapsed after FML solver: 1.9389228820800781.
# time elapsed after likelihood estimation: 2.905366897583008.
# time elapsed after logit revenue optimization: 2.918195962905884.
# run: 30.
# time elapsed after FML solver: 2.156221866607666.
# time elapsed after likelihood estimation: 3.0720560550689697.
# time elapsed after logit revenue optimization: 3.150804042816162.
# run: 31.
# time elapsed after FML solver: 1.738131046295166.
# time elapsed after likelihood estimation: 2.305145263671875.
# time elapsed after logit revenue optimization: 2.3753840923309326.
# run: 32.
# time elapsed after FML solver: 1.5512919425964355.
# time elapsed after likelihood estimation: 2.0235230922698975.
# time elapsed after logit revenue optimization: 2.065586805343628.
# run: 33.
# time elapsed after FML solver: 2.6254568099975586.
# time elapsed after likelihood estimation: 3.180285930633545.
# time elapsed after logit revenue optimization: 3.23923397064209.
# run: 34.
# time elapsed after FML solver: 1.6201319694519043.
# time elapsed after likelihood estimation: 2.522390127182007.
# time elapsed after logit revenue optimization: 2.5875682830810547.
# run: 35.
# time elapsed after FML solver: 1.744145154953003.
# time elapsed after likelihood estimation: 2.6712679862976074.
# time elapsed after logit revenue optimization: 2.727982997894287.
# run: 36.
# time elapsed after FML solver: 1.0356333255767822.
# time elapsed after likelihood estimation: 1.553574800491333.
# time elapsed after logit revenue optimization: 1.5985510349273682.
# run: 37.
# time elapsed after FML solver: 1.7246999740600586.
# time elapsed after likelihood estimation: 2.487122058868408.
# time elapsed after logit revenue optimization: 2.5495409965515137.
# run: 38.
# time elapsed after FML solver: 2.7610042095184326.
# time elapsed after likelihood estimation: 3.6100757122039795.
# time elapsed after logit revenue optimization: 3.6745588779449463.
# run: 39.
# time elapsed after FML solver: 2.440253973007202.
# time elapsed after likelihood estimation: 3.046581983566284.
# time elapsed after logit revenue optimization: 3.066631317138672.
# run: 40.
# time elapsed after FML solver: 1.6492443084716797.
# time elapsed after likelihood estimation: 2.3135223388671875.
# time elapsed after logit revenue optimization: 2.434519052505493.
# run: 41.
# time elapsed after FML solver: 1.1388258934020996.
# time elapsed after likelihood estimation: 1.7438666820526123.
# time elapsed after logit revenue optimization: 1.7780086994171143.
# run: 42.
# time elapsed after FML solver: 2.6305480003356934.
# time elapsed after likelihood estimation: 3.1967122554779053.
# time elapsed after logit revenue optimization: 3.2218692302703857.
# run: 43.
# time elapsed after FML solver: 2.172739028930664.
# time elapsed after likelihood estimation: 2.767620086669922.
# time elapsed after logit revenue optimization: 2.8191983699798584.
# run: 44.
# time elapsed after FML solver: 1.7320160865783691.
# time elapsed after likelihood estimation: 2.59608793258667.
# time elapsed after logit revenue optimization: 2.6353919506073.
# run: 45.
# time elapsed after FML solver: 1.3657588958740234.
# time elapsed after likelihood estimation: 1.8314929008483887.
# time elapsed after logit revenue optimization: 1.9135968685150146.
# run: 46.
# time elapsed after FML solver: 1.5327160358428955.
# time elapsed after likelihood estimation: 1.9956738948822021.
# time elapsed after logit revenue optimization: 2.0367839336395264.
# run: 47.
# time elapsed after FML solver: 1.147197961807251.
# time elapsed after likelihood estimation: 1.9111790657043457.
# time elapsed after logit revenue optimization: 1.9395561218261719.
# run: 48.
# time elapsed after FML solver: 2.050429105758667.
# time elapsed after likelihood estimation: 2.701634168624878.
# time elapsed after logit revenue optimization: 2.7875442504882812.
# run: 49.
# time elapsed after FML solver: 2.441147804260254.
# time elapsed after likelihood estimation: 2.9936301708221436.
# time elapsed after logit revenue optimization: 3.024092197418213.
# run: 50.
# time elapsed after FML solver: 3.9921159744262695.
# time elapsed after likelihood estimation: 4.465831756591797.
# time elapsed after logit revenue optimization: 4.519998788833618.
# run: 51.
# time elapsed after FML solver: 0.8847689628601074.
# time elapsed after likelihood estimation: 1.3097789287567139.
# time elapsed after logit revenue optimization: 1.3851039409637451.
# run: 52.
# time elapsed after FML solver: 1.6235520839691162.
# time elapsed after likelihood estimation: 2.227145195007324.
# time elapsed after logit revenue optimization: 2.311744213104248.
# run: 53.
# time elapsed after FML solver: 1.2508869171142578.
# time elapsed after likelihood estimation: 1.6610691547393799.
# time elapsed after logit revenue optimization: 1.7414069175720215.
# run: 54.
# time elapsed after FML solver: 2.6853108406066895.
# time elapsed after likelihood estimation: 3.49566912651062.
# time elapsed after logit revenue optimization: 3.5266029834747314.
# run: 55.
# time elapsed after FML solver: 1.8403401374816895.
# time elapsed after likelihood estimation: 2.5772359371185303.
# time elapsed after logit revenue optimization: 2.6032867431640625.
# run: 56.
# time elapsed after FML solver: 1.1011850833892822.
# time elapsed after likelihood estimation: 1.586280107498169.
# time elapsed after logit revenue optimization: 1.6973950862884521.
# run: 57.
# time elapsed after FML solver: 1.9344699382781982.
# time elapsed after likelihood estimation: 2.538616895675659.
# time elapsed after logit revenue optimization: 2.5776288509368896.
# run: 58.
# time elapsed after FML solver: 1.7418591976165771.
# time elapsed after likelihood estimation: 2.5562729835510254.
# time elapsed after logit revenue optimization: 2.658050060272217.
# run: 59.
# time elapsed after FML solver: 2.0278029441833496.
# time elapsed after likelihood estimation: 2.9429590702056885.
# time elapsed after logit revenue optimization: 2.9965009689331055.
# run: 60.
# time elapsed after FML solver: 1.5397210121154785.
# time elapsed after likelihood estimation: 2.1246840953826904.
# time elapsed after logit revenue optimization: 2.1658008098602295.
# run: 61.
# time elapsed after FML solver: 2.0588250160217285.
# time elapsed after likelihood estimation: 2.689927339553833.
# time elapsed after logit revenue optimization: 2.7430241107940674.
# run: 62.
# time elapsed after FML solver: 4.027655839920044.
# time elapsed after likelihood estimation: 4.837726354598999.
# time elapsed after logit revenue optimization: 4.871279239654541.
# run: 63.
# time elapsed after FML solver: 2.54398512840271.
# time elapsed after likelihood estimation: 3.477181911468506.
# time elapsed after logit revenue optimization: 3.5034139156341553.
# run: 64.
# time elapsed after FML solver: 1.5316369533538818.
# time elapsed after likelihood estimation: 2.1259829998016357.
# time elapsed after logit revenue optimization: 2.1570210456848145.
# run: 65.
# time elapsed after FML solver: 1.9219446182250977.
# time elapsed after likelihood estimation: 2.5176827907562256.
# time elapsed after logit revenue optimization: 2.5459048748016357.
# run: 66.
# time elapsed after FML solver: 1.9696900844573975.
# time elapsed after likelihood estimation: 2.633388042449951.
# time elapsed after logit revenue optimization: 2.6614670753479004.
# run: 67.
# time elapsed after FML solver: 1.6277718544006348.
# time elapsed after likelihood estimation: 2.2808470726013184.
# time elapsed after logit revenue optimization: 2.3376569747924805.
# run: 68.
# time elapsed after FML solver: 2.2800798416137695.
# time elapsed after likelihood estimation: 3.0252809524536133.
# time elapsed after logit revenue optimization: 3.0702011585235596.
# run: 69.
# time elapsed after FML solver: 3.0491158962249756.
# time elapsed after likelihood estimation: 3.931302309036255.
# time elapsed after logit revenue optimization: 3.9745640754699707.
# run: 70.
# time elapsed after FML solver: 1.1305968761444092.
# time elapsed after likelihood estimation: 1.9718377590179443.
# time elapsed after logit revenue optimization: 2.0269298553466797.
# run: 71.
# time elapsed after FML solver: 1.4927821159362793.
# time elapsed after likelihood estimation: 2.0509159564971924.
# time elapsed after logit revenue optimization: 2.1523468494415283.
# run: 72.
# time elapsed after FML solver: 1.6129028797149658.
# time elapsed after likelihood estimation: 2.1191999912261963.
# time elapsed after logit revenue optimization: 2.172067165374756.
# run: 73.
# time elapsed after FML solver: 1.7442028522491455.
# time elapsed after likelihood estimation: 2.2182440757751465.
# time elapsed after logit revenue optimization: 2.2610371112823486.
# run: 74.
# time elapsed after FML solver: 3.1663131713867188.
# time elapsed after likelihood estimation: 3.9571077823638916.
# time elapsed after logit revenue optimization: 3.9953746795654297.
# run: 75.
# time elapsed after FML solver: 2.6411941051483154.
# time elapsed after likelihood estimation: 3.539365768432617.
# time elapsed after logit revenue optimization: 3.5719470977783203.
# run: 76.
# time elapsed after FML solver: 2.7440271377563477.
# time elapsed after likelihood estimation: 3.343975782394409.
# time elapsed after logit revenue optimization: 3.429372787475586.
# run: 77.
# time elapsed after FML solver: 1.9453861713409424.
# time elapsed after likelihood estimation: 2.4711029529571533.
# time elapsed after logit revenue optimization: 2.52297306060791.
# run: 78.
# time elapsed after FML solver: 1.1567270755767822.
# time elapsed after likelihood estimation: 1.7213711738586426.
# time elapsed after logit revenue optimization: 1.7628710269927979.
# run: 79.
# time elapsed after FML solver: 1.9304170608520508.
# time elapsed after likelihood estimation: 2.6047821044921875.
# time elapsed after logit revenue optimization: 2.6245200634002686.
# run: 80.
# time elapsed after FML solver: 1.932291030883789.
# time elapsed after likelihood estimation: 2.5396840572357178.
# time elapsed after logit revenue optimization: 2.6074438095092773.
# run: 81.
# time elapsed after FML solver: 3.1701600551605225.
# time elapsed after likelihood estimation: 3.816573143005371.
# time elapsed after logit revenue optimization: 3.8605430126190186.
# run: 82.
# time elapsed after FML solver: 1.6098778247833252.
# time elapsed after likelihood estimation: 2.493630886077881.
# time elapsed after logit revenue optimization: 2.53662371635437.
# run: 83.
# time elapsed after FML solver: 2.3467628955841064.
# time elapsed after likelihood estimation: 2.906630039215088.
# time elapsed after logit revenue optimization: 2.951613187789917.
# run: 84.
# time elapsed after FML solver: 2.2167110443115234.
# time elapsed after likelihood estimation: 2.948101758956909.
# time elapsed after logit revenue optimization: 2.977266788482666.
# run: 85.
# time elapsed after FML solver: 2.051060914993286.
# time elapsed after likelihood estimation: 2.580821990966797.
# time elapsed after logit revenue optimization: 2.650946855545044.
# run: 86.
# time elapsed after FML solver: 1.3533439636230469.
# time elapsed after likelihood estimation: 1.969994068145752.
# time elapsed after logit revenue optimization: 2.019562005996704.
# run: 87.
# time elapsed after FML solver: 2.0286829471588135.
# time elapsed after likelihood estimation: 2.7082679271698.
# time elapsed after logit revenue optimization: 2.81648588180542.
# run: 88.
# time elapsed after FML solver: 1.688868761062622.
# time elapsed after likelihood estimation: 2.265253782272339.
# time elapsed after logit revenue optimization: 2.3053767681121826.
# run: 89.
# time elapsed after FML solver: 2.911383867263794.
# time elapsed after likelihood estimation: 3.4576592445373535.
# time elapsed after logit revenue optimization: 3.5430901050567627.
# run: 90.
# time elapsed after FML solver: 2.734440803527832.
# time elapsed after likelihood estimation: 3.2935867309570312.
# time elapsed after logit revenue optimization: 3.391915798187256.
# run: 91.
# time elapsed after FML solver: 1.8225970268249512.
# time elapsed after likelihood estimation: 2.800762176513672.
# time elapsed after logit revenue optimization: 2.843266010284424.
# run: 92.
# time elapsed after FML solver: 1.6202707290649414.
# time elapsed after likelihood estimation: 2.195749044418335.
# time elapsed after logit revenue optimization: 2.248887062072754.
# run: 93.
# time elapsed after FML solver: 3.816519021987915.
# time elapsed after likelihood estimation: 4.280948877334595.
# time elapsed after logit revenue optimization: 4.3194780349731445.
# run: 94.
# time elapsed after FML solver: 2.7678520679473877.
# time elapsed after likelihood estimation: 3.2466089725494385.
# time elapsed after logit revenue optimization: 3.2994072437286377.
# run: 95.
# time elapsed after FML solver: 1.5100407600402832.
# time elapsed after likelihood estimation: 2.07543683052063.
# time elapsed after logit revenue optimization: 2.1269209384918213.
# run: 96.
# time elapsed after FML solver: 3.09181809425354.
# time elapsed after likelihood estimation: 3.5386250019073486.
# time elapsed after logit revenue optimization: 3.582014322280884.
# run: 97.
# time elapsed after FML solver: 2.372668981552124.
# time elapsed after likelihood estimation: 3.0467100143432617.
# time elapsed after logit revenue optimization: 3.0788118839263916.
# run: 98.
# time elapsed after FML solver: 2.799405097961426.
# time elapsed after likelihood estimation: 3.332371950149536.
# time elapsed after logit revenue optimization: 3.4111480712890625.
# run: 99.
# time elapsed after FML solver: 1.6171441078186035.
# time elapsed after likelihood estimation: 2.2207469940185547.
# time elapsed after logit revenue optimization: 2.3170931339263916.
# m: 4.
# run: 0.
# time elapsed after FML solver: 8.340191125869751.
# time elapsed after likelihood estimation: 8.860319137573242.
# time elapsed after logit revenue optimization: 8.913028001785278.
# run: 1.
# time elapsed after FML solver: 11.760509014129639.
# time elapsed after likelihood estimation: 12.634615659713745.
# time elapsed after logit revenue optimization: 12.709576845169067.
# run: 2.
# time elapsed after FML solver: 9.42589783668518.
# time elapsed after likelihood estimation: 9.99399209022522.
# time elapsed after logit revenue optimization: 10.12995719909668.
# run: 3.
# time elapsed after FML solver: 18.516374111175537.
# time elapsed after likelihood estimation: 19.160921096801758.
# time elapsed after logit revenue optimization: 19.21583104133606.
# run: 4.
# time elapsed after FML solver: 9.831892967224121.
# time elapsed after likelihood estimation: 10.503719329833984.
# time elapsed after logit revenue optimization: 10.547451257705688.
# run: 5.
# time elapsed after FML solver: 145.99399399757385.
# time elapsed after likelihood estimation: 147.0383861064911.
# time elapsed after logit revenue optimization: 147.09446096420288.
# run: 6.
# time elapsed after FML solver: 11.045459985733032.
# time elapsed after likelihood estimation: 11.737657070159912.
# time elapsed after logit revenue optimization: 11.816987037658691.
# run: 7.
# time elapsed after FML solver: 20.186851024627686.
# time elapsed after likelihood estimation: 20.752996921539307.
# time elapsed after logit revenue optimization: 20.808979034423828.
# run: 8.
# time elapsed after FML solver: 13.197486162185669.
# time elapsed after likelihood estimation: 14.078423023223877.
# time elapsed after logit revenue optimization: 14.126628875732422.
# run: 9.
# time elapsed after FML solver: 32.03401184082031.
# time elapsed after likelihood estimation: 32.59203314781189.
# time elapsed after logit revenue optimization: 32.65772104263306.
# run: 10.
# time elapsed after FML solver: 7.714379072189331.
# time elapsed after likelihood estimation: 8.71566104888916.
# time elapsed after logit revenue optimization: 8.79250717163086.
# run: 11.
# time elapsed after FML solver: 35.108898639678955.
# time elapsed after likelihood estimation: 35.80457901954651.
# time elapsed after logit revenue optimization: 35.86538290977478.
# run: 12.
# time elapsed after FML solver: 20.291531085968018.
# time elapsed after likelihood estimation: 21.181647062301636.
# time elapsed after logit revenue optimization: 21.237395763397217.
# run: 13.
# time elapsed after FML solver: 13.668202877044678.
# time elapsed after likelihood estimation: 14.806503057479858.
# time elapsed after logit revenue optimization: 14.822866916656494.
# run: 14.
# time elapsed after FML solver: 11.931349039077759.
# time elapsed after likelihood estimation: 12.654350996017456.
# time elapsed after logit revenue optimization: 12.68875503540039.
# run: 15.
# time elapsed after FML solver: 108.15158605575562.
# time elapsed after likelihood estimation: 108.93335103988647.
# time elapsed after logit revenue optimization: 108.99162006378174.
# run: 16.
# time elapsed after FML solver: 7.593376159667969.
# time elapsed after likelihood estimation: 8.314618110656738.
# time elapsed after logit revenue optimization: 8.372331142425537.
# run: 17.
# time elapsed after FML solver: 74.50928020477295.
# time elapsed after likelihood estimation: 75.05951309204102.
# time elapsed after logit revenue optimization: 75.12930083274841.
# run: 18.
# time elapsed after FML solver: 71.94796085357666.
# time elapsed after likelihood estimation: 72.72759485244751.
# time elapsed after logit revenue optimization: 72.80678701400757.
# run: 19.
# time elapsed after FML solver: 12.063273906707764.
# time elapsed after likelihood estimation: 12.891551971435547.
# time elapsed after logit revenue optimization: 13.042329788208008.
# run: 20.
# time elapsed after FML solver: 38.989373207092285.
# time elapsed after likelihood estimation: 39.63798522949219.
# time elapsed after logit revenue optimization: 39.70642805099487.
# run: 21.
# time elapsed after FML solver: 40.39816999435425.
# time elapsed after likelihood estimation: 41.015625.
# time elapsed after logit revenue optimization: 41.12500262260437.
# run: 22.
# time elapsed after FML solver: 15.407782793045044.
# time elapsed after likelihood estimation: 16.049078941345215.
# time elapsed after logit revenue optimization: 16.224927186965942.
# run: 23.
# time elapsed after FML solver: 17.225008964538574.
# time elapsed after likelihood estimation: 18.362056016921997.
# time elapsed after logit revenue optimization: 18.38669204711914.
# run: 24.
# time elapsed after FML solver: 45.52076292037964.
# time elapsed after likelihood estimation: 46.31614398956299.
# time elapsed after logit revenue optimization: 46.36968994140625.
# run: 25.
# time elapsed after FML solver: 16.227099895477295.
# time elapsed after likelihood estimation: 17.03817391395569.
# time elapsed after logit revenue optimization: 17.14630699157715.
# run: 26.
# time elapsed after FML solver: 128.18408679962158.
# time elapsed after likelihood estimation: 128.8265380859375.
# time elapsed after logit revenue optimization: 128.92665195465088.
# run: 27.
# time elapsed after FML solver: 10.109970808029175.
# time elapsed after likelihood estimation: 10.688693046569824.
# time elapsed after logit revenue optimization: 10.746354818344116.
# run: 28.
# time elapsed after FML solver: 32.95873427391052.
# time elapsed after likelihood estimation: 33.71839118003845.
# time elapsed after logit revenue optimization: 33.75619912147522.
# run: 29.
# time elapsed after FML solver: 27.739675998687744.
# time elapsed after likelihood estimation: 28.37317419052124.
# time elapsed after logit revenue optimization: 28.453161001205444.
# run: 30.
# time elapsed after FML solver: 15.67127013206482.
# time elapsed after likelihood estimation: 16.33903408050537.
# time elapsed after logit revenue optimization: 16.36676001548767.
# run: 31.
# time elapsed after FML solver: 17.58096194267273.
# time elapsed after likelihood estimation: 18.17232894897461.
# time elapsed after logit revenue optimization: 18.219470739364624.
# run: 32.
# time elapsed after FML solver: 25.926944971084595.
# time elapsed after likelihood estimation: 26.860936880111694.
# time elapsed after logit revenue optimization: 26.910916805267334.
# run: 33.
# time elapsed after FML solver: 18.114524364471436.
# time elapsed after likelihood estimation: 18.981303930282593.
# time elapsed after logit revenue optimization: 19.044448137283325.
# run: 34.
# time elapsed after FML solver: 59.84938979148865.
# time elapsed after likelihood estimation: 60.445250034332275.
# time elapsed after logit revenue optimization: 60.49991416931152.
# run: 35.
# time elapsed after FML solver: 60.59913873672485.
# time elapsed after likelihood estimation: 61.60198998451233.
# time elapsed after logit revenue optimization: 61.63004994392395.
# run: 36.
# time elapsed after FML solver: 22.04127788543701.
# time elapsed after likelihood estimation: 22.812792778015137.
# time elapsed after logit revenue optimization: 22.958093881607056.
# run: 37.
# time elapsed after FML solver: 10.77929973602295.
# time elapsed after likelihood estimation: 11.497750043869019.
# time elapsed after logit revenue optimization: 11.57585597038269.
# run: 38.
# time elapsed after FML solver: 23.34283995628357.
# time elapsed after likelihood estimation: 24.166100025177002.
# time elapsed after logit revenue optimization: 24.193648099899292.
# run: 39.
# time elapsed after FML solver: 42.08364701271057.
# time elapsed after likelihood estimation: 42.99580216407776.
# time elapsed after logit revenue optimization: 43.05393409729004.
# run: 40.
# time elapsed after FML solver: 74.59246611595154.
# time elapsed after likelihood estimation: 75.43238091468811.
# time elapsed after logit revenue optimization: 75.4875738620758.
# run: 41.
# time elapsed after FML solver: 101.17128396034241.
# time elapsed after likelihood estimation: 101.84414601325989.
# time elapsed after logit revenue optimization: 101.92659711837769.
# run: 42.
# time elapsed after FML solver: 192.30453300476074.
# time elapsed after likelihood estimation: 192.91364526748657.
# time elapsed after logit revenue optimization: 192.9905071258545.
# run: 43.
# time elapsed after FML solver: 32.457700967788696.
# time elapsed after likelihood estimation: 33.03137016296387.
# time elapsed after logit revenue optimization: 33.07530903816223.
# run: 44.
# time elapsed after FML solver: 7.274311780929565.
# time elapsed after likelihood estimation: 7.8851940631866455.
# time elapsed after logit revenue optimization: 7.984521865844727.
# run: 45.
# time elapsed after FML solver: 1016.1200850009918.
# time elapsed after likelihood estimation: 1016.6897983551025.
# time elapsed after logit revenue optimization: 1016.7739593982697.
# run: 46.
# time elapsed after FML solver: 15.999549150466919.
# time elapsed after likelihood estimation: 17.397156238555908.
# time elapsed after logit revenue optimization: 17.50274634361267.
# run: 47.
# time elapsed after FML solver: 27.38784909248352.
# time elapsed after likelihood estimation: 28.30259084701538.
# time elapsed after logit revenue optimization: 28.368515729904175.
# run: 48.
# time elapsed after FML solver: 13.75426197052002.
# time elapsed after likelihood estimation: 14.33923077583313.
# time elapsed after logit revenue optimization: 14.42658281326294.
# run: 49.
# time elapsed after FML solver: 86.3484559059143.
# time elapsed after likelihood estimation: 87.04416704177856.
# time elapsed after logit revenue optimization: 87.10234713554382.
# run: 50.
# time elapsed after FML solver: 7.444273948669434.
# time elapsed after likelihood estimation: 7.9923529624938965.
# time elapsed after logit revenue optimization: 8.085134744644165.
# run: 51.
# time elapsed after FML solver: 11.14211392402649.
# time elapsed after likelihood estimation: 11.740506172180176.
# time elapsed after logit revenue optimization: 11.817251205444336.
# run: 52.
# time elapsed after FML solver: 14.532620668411255.
# time elapsed after likelihood estimation: 15.477466821670532.
# time elapsed after logit revenue optimization: 15.541435718536377.
# run: 53.
# time elapsed after FML solver: 6957.997709035873.
# time elapsed after likelihood estimation: 6958.920157909393.
# time elapsed after logit revenue optimization: 6958.993356704712.
# run: 54.
# time elapsed after FML solver: 29.600962162017822.
# time elapsed after likelihood estimation: 41.66830897331238.
# time elapsed after logit revenue optimization: 41.7356960773468.
# run: 55.
# time elapsed after FML solver: 4.058082103729248.
# time elapsed after likelihood estimation: 4.932994842529297.
# time elapsed after logit revenue optimization: 4.99846887588501.
# run: 56.
# time elapsed after FML solver: 18.936310052871704.
# time elapsed after likelihood estimation: 19.73863983154297.
# time elapsed after logit revenue optimization: 19.827478885650635.
# run: 57.
# time elapsed after FML solver: 11.673676013946533.
# time elapsed after likelihood estimation: 12.45913290977478.
# time elapsed after logit revenue optimization: 12.542689085006714.
# run: 58.
# time elapsed after FML solver: 17.14188814163208.
# time elapsed after likelihood estimation: 17.773303985595703.
# time elapsed after logit revenue optimization: 17.86445426940918.
# run: 59.
# time elapsed after FML solver: 271.8150007724762.
# time elapsed after likelihood estimation: 272.5022358894348.
# time elapsed after logit revenue optimization: 272.5633018016815.
# run: 60.
# time elapsed after FML solver: 16.64455795288086.
# time elapsed after likelihood estimation: 17.619911909103394.
# time elapsed after logit revenue optimization: 17.716880083084106.
# run: 61.
# time elapsed after FML solver: 64.46656703948975.
# time elapsed after likelihood estimation: 65.40965723991394.
# time elapsed after logit revenue optimization: 65.44336104393005.
# run: 62.
# time elapsed after FML solver: 36.0819251537323.
# time elapsed after likelihood estimation: 36.68644380569458.
# time elapsed after logit revenue optimization: 36.77665090560913.
# run: 63.
# time elapsed after FML solver: 6.620959997177124.
# time elapsed after likelihood estimation: 7.282287836074829.
# time elapsed after logit revenue optimization: 7.416369915008545.
# run: 64.
# time elapsed after FML solver: 80.26726579666138.
# time elapsed after likelihood estimation: 80.97473978996277.
# time elapsed after logit revenue optimization: 81.04327178001404.
# run: 65.
# time elapsed after FML solver: 236.82418394088745.
# time elapsed after likelihood estimation: 237.48368096351624.
# time elapsed after logit revenue optimization: 237.5357267856598.
# run: 66.
# time elapsed after FML solver: 14.759151697158813.
# time elapsed after likelihood estimation: 15.737514972686768.
# time elapsed after logit revenue optimization: 15.808626890182495.
# run: 67.
# time elapsed after FML solver: 52.162070989608765.
# time elapsed after likelihood estimation: 52.826021909713745.
# time elapsed after logit revenue optimization: 52.87434387207031.
# run: 68.
# time elapsed after FML solver: 15.258002996444702.
# time elapsed after likelihood estimation: 15.96806001663208.
# time elapsed after logit revenue optimization: 16.009126901626587.
# run: 69.
# time elapsed after FML solver: 68.42012023925781.
# time elapsed after likelihood estimation: 68.96825504302979.
# time elapsed after logit revenue optimization: 69.03418803215027.
# run: 70.
# time elapsed after FML solver: 57.74263310432434.
# time elapsed after likelihood estimation: 58.756049156188965.
# time elapsed after logit revenue optimization: 58.89782118797302.
# run: 71.
# time elapsed after FML solver: 2.7531967163085938.
# time elapsed after likelihood estimation: 3.7221648693084717.
# time elapsed after logit revenue optimization: 3.757369041442871.
# run: 72.
# time elapsed after FML solver: 34.16443109512329.
# time elapsed after likelihood estimation: 34.65126609802246.
# time elapsed after logit revenue optimization: 34.71462917327881.
# run: 73.
# time elapsed after FML solver: 37.82144117355347.
# time elapsed after likelihood estimation: 38.51451277732849.
# time elapsed after logit revenue optimization: 38.62329888343811.
# run: 74.
# time elapsed after FML solver: 32.82236695289612.
# time elapsed after likelihood estimation: 33.548583984375.
# time elapsed after logit revenue optimization: 33.58162784576416.
# run: 75.
# time elapsed after FML solver: 52.34234094619751.
# time elapsed after likelihood estimation: 52.878312826156616.
# time elapsed after logit revenue optimization: 52.958313941955566.
# run: 76.
# time elapsed after FML solver: 10.541143894195557.
# time elapsed after likelihood estimation: 11.212313890457153.
# time elapsed after logit revenue optimization: 11.266815900802612.
# run: 77.
# time elapsed after FML solver: 16.38100814819336.
# time elapsed after likelihood estimation: 17.16161584854126.
# time elapsed after logit revenue optimization: 17.221349954605103.
# run: 78.
# time elapsed after FML solver: 54.18049216270447.
# time elapsed after likelihood estimation: 54.883941888809204.
# time elapsed after logit revenue optimization: 54.96996879577637.
# run: 79.
# time elapsed after FML solver: 11.243088960647583.
# time elapsed after likelihood estimation: 12.197942972183228.
# time elapsed after logit revenue optimization: 12.22043514251709.
# run: 80.
# time elapsed after FML solver: 11.292509078979492.
# time elapsed after likelihood estimation: 11.831717252731323.
# time elapsed after logit revenue optimization: 11.88875699043274.
# run: 81.
# time elapsed after FML solver: 15.70083999633789.
# time elapsed after likelihood estimation: 16.64778709411621.
# time elapsed after logit revenue optimization: 16.703132152557373.
# run: 82.
# time elapsed after FML solver: 43.47617292404175.
# time elapsed after likelihood estimation: 44.011926889419556.
# time elapsed after logit revenue optimization: 44.08193492889404.
# run: 83.
# time elapsed after FML solver: 17.85031008720398.
# time elapsed after likelihood estimation: 18.403944969177246.
# time elapsed after logit revenue optimization: 18.48540496826172.
# run: 84.
# time elapsed after FML solver: 101.07478308677673.
# time elapsed after likelihood estimation: 102.14087200164795.
# time elapsed after logit revenue optimization: 102.20295810699463.
# run: 85.
# time elapsed after FML solver: 154.66339993476868.
# time elapsed after likelihood estimation: 155.49158382415771.
# time elapsed after logit revenue optimization: 155.64577507972717.
# run: 86.
# time elapsed after FML solver: 56.99945116043091.
# time elapsed after likelihood estimation: 57.810973167419434.
# time elapsed after logit revenue optimization: 57.829405069351196.
# run: 87.
# time elapsed after FML solver: 21.91518998146057.
# time elapsed after likelihood estimation: 22.64183020591736.
# time elapsed after logit revenue optimization: 22.715445041656494.
# run: 88.
# time elapsed after FML solver: 25.32174301147461.
# time elapsed after likelihood estimation: 26.1582670211792.
# time elapsed after logit revenue optimization: 26.21945095062256.
# run: 89.
# time elapsed after FML solver: 7.465383052825928.
# time elapsed after likelihood estimation: 8.414429903030396.
# time elapsed after logit revenue optimization: 8.438092947006226.
# run: 90.
# time elapsed after FML solver: 39.33132815361023.
# time elapsed after likelihood estimation: 40.11759114265442.
# time elapsed after logit revenue optimization: 40.2136390209198.
# run: 91.
# time elapsed after FML solver: 8.50562596321106.
# time elapsed after likelihood estimation: 9.304826259613037.
# time elapsed after logit revenue optimization: 9.374695301055908.
# run: 92.
# time elapsed after FML solver: 31.905208110809326.
# time elapsed after likelihood estimation: 32.472590923309326.
# time elapsed after logit revenue optimization: 32.514317750930786.
# run: 93.
# time elapsed after FML solver: 1133.5561451911926.
# time elapsed after likelihood estimation: 1134.4178099632263.
# time elapsed after logit revenue optimization: 1134.463984966278.
# run: 94.
# time elapsed after FML solver: 57.640352964401245.
# time elapsed after likelihood estimation: 59.287198066711426.
# time elapsed after logit revenue optimization: 59.34147810935974.
# run: 95.
# time elapsed after FML solver: 55.50641202926636.
# time elapsed after likelihood estimation: 56.38542580604553.
# time elapsed after logit revenue optimization: 56.4428448677063.
# run: 96.
# time elapsed after FML solver: 10.794658184051514.
# time elapsed after likelihood estimation: 11.674922943115234.
# time elapsed after logit revenue optimization: 11.712413787841797.
# run: 97.
# time elapsed after FML solver: 18.345453023910522.
# time elapsed after likelihood estimation: 19.279045820236206.
# time elapsed after logit revenue optimization: 19.343700885772705.
# run: 98.
# time elapsed after FML solver: 13.272924900054932.
# time elapsed after likelihood estimation: 14.209839820861816.
# time elapsed after logit revenue optimization: 14.305154800415039.
# run: 99.
# time elapsed after FML solver: 7.6493918895721436.
# time elapsed after likelihood estimation: 8.338242053985596.
# time elapsed after logit revenue optimization: 8.3819899559021.

# %%
observed_choices

# %%
# check if you take average loglikelihoog if you have to divide by n or sqrt(n)
# standard errors: https://stats.stackexchange.com/questions/68080/basic-question-about-fisher-information-matrix-and-relationship-to-hessian-and-s
standard_errors
# standard_errors
# Out:
# array([0.08612482, 0.09406891, 0.09521281, 0.07162577, 0.11699961,
#        0.12909529, 0.11300329, 0.08158962, 0.06631054, 0.07131954,
#        0.00034469, 0.00032515, 0.00023397, 0.00021443, 0.00016033,
#        0.00043511, 0.00017233, 0.00028399, 0.00014118, 0.00014423])

# %%
# test hypothesis that the value is different from the real value? true value in CI ?
